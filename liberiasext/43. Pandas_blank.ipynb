# %% [markdown]
# # Introducción a Pandas

# %% [markdown]
# [Pandas](https://pandas.pydata.org/about/index.html) es una librería que proporciona estructuras de datos y herramientas de análisis de datos de alto rendimiento y fáciles de usar.
# * La estructura de datos principal es el DataFrame, que puede considerarse como una tabla 2D en memoria (como una hoja de cálculo, con nombres de columna y etiquetas de fila).
# * Muchas funciones disponibles en Excel están disponibles mediante programación, como crear tablas dinámicas, calcular columnas basadas en otras columnas, trazar gráficos, etc.
# * Proporciona un alto rendimiento para manipular (unir, dividir, modificar…) grandes conjuntos de datos

# %% [markdown]
# ## Import

# %%
import pandas as pd

# %% [markdown]
# ## Estructuras de datos en Pandas

# %% [markdown]
# La librería Pandas, de manera genérica, contiene las siguientes estructuras de datos:
# * **Series**: Array de una dimensión
# * **DataFrame**: Se corresponde con una tabla de 2 dimensiones
# * **Panel**: Similar a un diccionario de DataFrames

# %% [markdown]
# ## Creación del objeto Series

# %%
# Creacion de un objeto Series
var = pd.Series([0,1,2,3])

# %%
# Creación de un objeto Series inicializándolo con un diccionario de Python
altura = {1: 1.60, 2: 1.78, 3: 1.65}
s = pd.Series(altura)
print(s)
# Out:
# 1    1.60
# 2    1.78
# 3    1.65
# dtype: float64

# %%
# Creación de un objeto Series inicializándolo con algunos
# de los elementos de un diccionario de Python
# Creación de un objeto Series inicializándolo con un diccionario de Python
altura = {"Chelo": 1.60, "Paula": 1.78, 3: 1.65}
s = pd.Series(altura, index=["Chelo", "Paula"])
print(s)
# Out:
# Chelo    1.60
# Paula    1.78
# dtype: float64

# %%
# Creación de un objeto Series inicializandolo con un escalar
s = pd.Series(42, ["columna3", "columna4", "columna69"])
print(s)
# Out:
# columna3     42
# columna4     42
# columna69    42
# dtype: int64

# %% [markdown]
# ## Acceso a los elementos de un objeto Series

# %% [markdown]
# Cada elemento en un objeto Series tiene un identificador único que se denomina **_index label_**.

# %%
# Creación de un objeto Series
s = pd.Series([2,4,6,8], index = ["num1", "num2", "num3","num4"])
print(s)
# Out:
# num1    2
# num2    4
# num3    6
# num4    8
# dtype: int64

# %%
# Accediendo al tercer elemento del objeto
s["num3"]
# Out:
# 6

# %%
# Tambien se puede acceder al elemento por posición
s[2]
# Out:
# 6

# %%
# loc es la forma estándar de acceder a un elemento de un objeto Series por atributo
s.loc["num3"]
# Out:
# 6

# %%
# iloc es la forma estándar de acceder a un elemento de un objeto Series por posición
s.iloc[2]
# Out:
# 6

# %%
# Accediendo al segundo y tercer elemento por posición
s.iloc[2:4]
# Out:
# num3    6
# num4    8
# dtype: int64

# %% [markdown]
# ## Operaciones aritméticas con Series

# %%
# Creacion de un objeto Series
serie1 = pd.Series([1,2,3], index = ["num1", "num12312", "num31231"])

# %%
# Los objeto Series son similares y compatibles con los Arrays de Numpy
import numpy as np
# Ufunc de Numpy para sumar los elementos de un Array
serie2 = pd.Series([-1,-2,-3], index = ["num1", "num2", "num3"])
np.sum(serie1)
# Out:
# 6

# %%
# El resto de operaciones aritméticas de Numpy sobre Arrays también son posibles
# Más información al respecto en la Introducción a Numpy
s*2
# Out:
# num1     4
# num2     8
# num3    12
# num4    16
# dtype: int64

# %% [markdown]
# ## Representación gráfica de un objeto Series

# %%
# Creación de un objeto Series denominado Temperaturas
serie3 = pd.Series([2,4,6,8,10])

# %%
# Representación gráfica del objeto Series
# %matplotlib inline
import matplotlib.pyplot as plt

serie3.plot()
plt.show()

# %% [markdown]
# ## Creación de un objeto DataFrame

# %%
# Creación de un DataFrame inicializándolo con un diccionario de objetios Series
s =

# %% [markdown]
# Puede forzarse al DataFrame a que presente unas columnas determinadas y en un orden determinado

# %%
# Creación de un DataFrame inicializándolo con algunos elementos de un diccionario
# de objetos Series
personas = {
    "peso": pd.Series([84, 90, 56, 64], ["Santiago","Pedro", "Ana", "Julia"]),
    "altura": pd.Series({"Santiago": 187, "Pedro": 178, "Julia": 170, "Ana": 165}),
    "hijos": pd.Series([2, 3], ["Pedro", "Julia"])
}

df = pd.DataFrame(personas)
df
# Out:
#           peso  altura  hijos
# Ana         56     165    NaN
# Julia       64     170    3.0
# Pedro       90     178    2.0
# Santiago    84     187    NaN
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df, *['peso'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df, *['altura'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df, *['hijos'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plot(df, x_colname, y_colname, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(6 * figscale, 6 * figscale))
#   df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha)
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plot(df, *['peso', 'altura'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plot(df, x_colname, y_colname, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(6 * figscale, 6 * figscale))
#   df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha)
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plot(df, *['altura', 'hijos'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df, *['altura', 'peso', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df, *['altura', 'hijos', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df, *['altura', 'count()', None], **{})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df, *['peso'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df, *['altura'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df, *['hijos'], **{})
# chart

# %%
# Creación de un DataFrame inicializándolo con una lista de listas de Python
# Importante: Deben especificarse las columnas e indices por separado
valores = [
    [185, 4, 76],
    [170, 0, 65],
    [190, 1, 89]
]

# %%
# Creación de un DataFrame inicializándolo con un diccionario de Python
personas = {
    "altura": {"Santiago": 187, "Pedro": 178, "Julia": 170, "Ana": 165},
    "peso": {"Santiago": 87, "Pedro": 78, "Julia": 70, "Ana": 65}}
df = pd.DataFrame(personas)
df
# Out:
#           altura  peso
# Santiago     187    87
# Pedro        178    78
# Julia        170    70
# Ana          165    65

# %% [markdown]
# ## Acceso a los elementos de un DataFrame

# %%
# Creación de un DataFrame inicializándolo con un diccionario de objetios Series
personas = {
    "peso": pd.Series([84, 90, 56, 64], ["Santiago","Pedro", "Ana", "Julia"]),
    "altura": pd.Series({"Santiago": 187, "Pedro": 178, "Julia": 170, "Ana": 165}),
    "hijos": pd.Series([2, 3], ["Pedro", "Julia"])
}

# %% [markdown]
# ### Acceso a los elementos de las columnas del DataFrame

# %%
df["peso"]
# Out:
# Santiago    87
# Pedro       78
# Julia       70
# Ana         65
# Name: peso, dtype: int64

# %%
df["peso"][1:3]
# Out:
# Pedro    78
# Julia    70
# Name: peso, dtype: int64

# %%
# Pueden combinarse los metodos anteriores con expresiones booleanas
df[df["peso"] > 80]
# Out:
#           altura  peso
# Santiago     187    87

# %%
# Pueden combinarse los metodos anteriores con expresiones booleanas
df[(df["peso"]>80) & (df["altura"])]
# Out:
#           altura  peso
# Santiago     187    87

# %% [markdown]
# ### Acceso a los elementos de las filas del DataFrame

# %%
# Mostrar el DataFrame
df
# Out:
#           altura  peso
# Santiago     187    87
# Pedro        178    78
# Julia        170    70
# Ana          165    65

# %%
df.loc["Santiago"]
# Out:
# altura    187
# peso       87
# Name: Santiago, dtype: int64

# %%
df.iloc[2]
# Out:
# altura    170
# peso       70
# Name: Julia, dtype: int64

# %%
df.iloc[1:3]
# Out:
#        altura  peso
# Pedro     178    78
# Julia     170    70

# %% [markdown]
# ### Consulta avanzada de los elementos de un DataFrame

# %%
# Mostrar el DataFrame
df
# Out:
#           altura  peso
# Santiago     187    87
# Pedro        178    78
# Julia        170    70
# Ana          165    65

# %%
df.query("altura>170 and peso>60")
# Out:
#           altura  peso
# Santiago     187    87
# Pedro        178    78

# %% [markdown]
# ## Copiar un DataFrame

# %%
# Creación de un DataFrame inicializándolo con un diccionario de objetios Series
personas = {
    "peso": pd.Series([84, 90, 56, 64], ["Santiago","Pedro", "Ana", "Julia"]),
    "altura": pd.Series({"Santiago": 187, "Pedro": 178, "Julia": 170, "Ana": 165}),
    "hijos": pd.Series([2, 3], ["Pedro", "Julia"])
}
df2 = pd.DataFrame(personas)
df2
# Out:
#           peso  altura  hijos
# Ana         56     165    NaN
# Julia       64     170    3.0
# Pedro       90     178    2.0
# Santiago    84     187    NaN

# %%
# Copia del DataFrame df en df_copy
# Importante: Al modificar un elemento de df_copy no se modifica df
df_copy = df.copy()

# %% [markdown]
# ## Modificación de un DataFrame

# %%
# Creación de un DataFrame inicializándolo con un diccionario de objetios Series
personas = {
    "peso": pd.Series([84, 90, 56, 64], ["Santiago","Pedro", "Ana", "Julia"]),
    "altura": pd.Series({"Santiago": 187, "Pedro": 178, "Julia": 170, "Ana": 165}),
    "hijos": pd.Series([2, 3], ["Pedro", "Julia"])
}

# %%
# Añadir una nueva columna al DataFrame
df["años"] =

# %%
# Añadir una nueva columna calculada al DataFrame

# %%
# Añadir una nueva columna creando un DataFrame nuevo
df_mod = df.assign(mascotas = [1,3,0,0])
df_mod
# Out:
#           altura  peso  mascotas
# Santiago     187    87         1
# Pedro        178    78         3
# Julia        170    70         0
# Ana          165    65         0

# %%
# Eliminar una columna existente del DataFrame
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-1914f6fee99e> in <cell line: 2>()
#       1 # Eliminar una columna existente del DataFrame
# ----> 2 df_mod  = df.drop(["hijos"], axis = 1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['hijos'] not found in axis"

# %%
# Eliminar una columna existente devolviendo una copia del DataFrame resultante

# %% [markdown]
# ## Evaluación de expresiones sobre un DataFrame

# %%
# Creación de un DataFrame inicializándolo con un diccionario de objetios Series
personas = {
    "peso": pd.Series([84, 90, 56, 64], ["Santiago","Pedro", "Ana", "Julia"]),
    "altura": pd.Series({"Santiago": 187, "Pedro": 178, "Julia": 170, "Ana": 165}),
    "hijos": pd.Series([2, 3], ["Pedro", "Julia"])
}

df = pd.DataFrame(personas)

# %%
# Evaluar una función sobre una columna del DataFrame
df.eval("altura/2")
# Out:
# Ana         82.5
# Julia       85.0
# Pedro       89.0
# Santiago    93.5
# dtype: float64

# %%
# Asignar el valor resultante como una nueva columna
df.eval("media_altura = altura/2", inplace = True)

# %%
# Evaluar una función utilizando una variable local
max_altura = 100
df.eval("altura>@max_altura")
# Out:
# Ana         True
# Julia       True
# Pedro       True
# Santiago    True
# dtype: bool

# %%
# Aplicar una función externa a una columna del DataFrame

# %% [markdown]
# ## Guardar y Cargar el DataFrame

# %%
# Creación de un DataFrame inicializándolo con un diccionario de objetios Series
personas = {
    "peso": pd.Series([84, 90, 56, 64], ["Santiago","Pedro", "Ana", "Julia"]),
    "altura": pd.Series({"Santiago": 187, "Pedro": 178, "Julia": 170, "Ana": 165}),
    "hijos": pd.Series([2, 3], ["Pedro", "Julia"])
}

df = pd.DataFrame(personas)
df
# Out:
#           peso  altura  hijos
# Ana         56     165    NaN
# Julia       64     170    3.0
# Pedro       90     178    2.0
# Santiago    84     187    NaN

# %%
# Guardar el DataFrame como CSV, HTML y JSON
df.to_csv("df_personas.csv")
df.to_html("df_personas.html")
df.to_json("df_personas.json")

# %%
# Cargar el DataFrame en Jupyter
df2 = pd.read_csv("df_personas.csv")

# %%
df2
# Out:
#   Unnamed: 0  peso  altura  hijos
# 0        Ana    56     165    NaN
# 1      Julia    64     170    3.0
# 2      Pedro    90     178    2.0
# 3   Santiago    84     187    NaN

# %%
# Cargar el DataFrame con la primera columna correctamente asignada
df2 = pd.read_csv("df_personas.csv", index_col = 0)

# %%
df2
# Out:
#           peso  altura  hijos
# Ana         56     165    NaN
# Julia       64     170    3.0
# Pedro       90     178    2.0
# Santiago    84     187    NaN

# %%
import requests
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup
import pandas as pd

paginador = 1
if paginador == 0:
    boohooshirt = requests.get( "https://www.boohooman.com/mens/tops/t-shirts")
else:
    boohooshirt = requests.get( "https://www.boohooman.com/mens/tops/t-shirts")
    boohoosoup = BeautifulSoup(boohooshirt.content)
    for descproducto in boohoosoup.find_all("div", {"class": "product-tile"}):
        productContainer = descproducto.find("div", {"class": "product-image"})
        productLink = productContainer.find("a").get("href")
        boohooproduct = requests.get("https://www.boohooman.com" + productLink)
        boohooproductsoup = BeautifulSoup(boohooproduct.content)
        productName = boohooproductsoup.find("h1", {"class": "product-name"}).get_text()
        productPrice = boohooproductsoup.find("div", {"class": "product-price"}).get_text().strip("\n")
        productDescContainer = boohooproductsoup.find("ul", {"class": "js-global-accordion"})
        productDescList = productDescContainer.find("li", {"id": "product-short-description-tab"})
        productDesc = productDescList.find("p").get_text()
        productCategory = productName.split(" ")
        productCategoryText = productCategory[-1]
        productImageContainer = boohooproductsoup.find("div", {"id": "product-primary-image"})
        productImage = productImageContainer.find("a").get("href")
        rowData = {
            "link": pd.Series({productName: ("https://www.boohooman.com" + productLink)}),
            "precio": pd.Series({ productName: productPrice }),
            "descripcion": pd.Series({productName: productDesc}),
            "categoria": pd.Series({ productName: productCategoryText }),
            "imagen": pd.Series({productName: ("https://media.boohooman.com/i/boohooman/" + productImage)})
        }
        print(rowData)
# Out:
# {'link': Active Training Dept Performance Slim T-shirt    https://www.boohooman.com/active-training-dept...
# dtype: object, 'precio': Active Training Dept Performance Slim T-shirt    \n\n\n£9.80\n( -30% )\n\n\n£14.00\n\n
# dtype: object, 'descripcion': Active Training Dept Performance Slim T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Active Training Dept Performance Slim T-shirt    T-shirt
# dtype: object, 'imagen': Active Training Dept Performance Slim T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Active Training Dept Performance Slim T-shirt    https://www.boohooman.com/active-training-dept...
# dtype: object, 'precio': Active Training Dept Performance Slim T-shirt    \n\n\n£9.80\n( -30% )\n\n\n£14.00\n\n
# dtype: object, 'descripcion': Active Training Dept Performance Slim T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Active Training Dept Performance Slim T-shirt    T-shirt
# dtype: object, 'imagen': Active Training Dept Performance Slim T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Plus Active Training Dept Performance T-shirt    https://www.boohooman.com/plus-active-training...
# dtype: object, 'precio': Plus Active Training Dept Performance T-shirt    \n\n\n£9.80\n( -30% )\n\n\n£14.00\n\n
# dtype: object, 'descripcion': Plus Active Training Dept Performance T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Plus Active Training Dept Performance T-shirt    T-shirt
# dtype: object, 'imagen': Plus Active Training Dept Performance T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Active Training Dept Performance Slim T-shirt    https://www.boohooman.com/active-training-dept...
# dtype: object, 'precio': Active Training Dept Performance Slim T-shirt    \n\n\n£9.80\n( -30% )\n\n\n£14.00\n\n
# dtype: object, 'descripcion': Active Training Dept Performance Slim T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Active Training Dept Performance Slim T-shirt    T-shirt
# dtype: object, 'imagen': Active Training Dept Performance Slim T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Tall Active Training Dept Performance Slim T-shirt    https://www.boohooman.com/tall-active-training...
# dtype: object, 'precio': Tall Active Training Dept Performance Slim T-shirt    \n\n\n£9.80\n( -30% )\n\n\n£14.00\n\n
# dtype: object, 'descripcion': Tall Active Training Dept Performance Slim T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Tall Active Training Dept Performance Slim T-shirt    T-shirt
# dtype: object, 'imagen': Tall Active Training Dept Performance Slim T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Tall Active Training Dept Performance Slim T-shirt    https://www.boohooman.com/tall-active-training...
# dtype: object, 'precio': Tall Active Training Dept Performance Slim T-shirt    \n\n\n£9.80\n( -30% )\n\n\n£14.00\n\n
# dtype: object, 'descripcion': Tall Active Training Dept Performance Slim T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Tall Active Training Dept Performance Slim T-shirt    T-shirt
# dtype: object, 'imagen': Tall Active Training Dept Performance Slim T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Rick & Morty License T-shirt    https://www.boohooman.com/oversized-rick-morty...
# dtype: object, 'precio': Oversized Rick & Morty License T-shirt    \n\n\n£15.40\n( -30% )\n\n\n£22.00\n\n
# dtype: object, 'descripcion': Oversized Rick & Morty License T-shirt    At boohooMAN, we only team up with the best an...
# dtype: object, 'categoria': Oversized Rick & Morty License T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Rick & Morty License T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Butterfly Back Print T-shirt    https://www.boohooman.com/oversized-butterfly-...
# dtype: object, 'precio': Oversized Butterfly Back Print T-shirt    \n\n\n£7.00\n( -30% )\n\n\n£10.00\n\n
# dtype: object, 'descripcion': Oversized Butterfly Back Print T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Oversized Butterfly Back Print T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Butterfly Back Print T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Pokemon Umbreon License T-shirt    https://www.boohooman.com/oversized-pokemon-um...
# dtype: object, 'precio': Oversized Pokemon Umbreon License T-shirt    \n\n\n£12.60\n( -30% )\n\n\n£18.00\n\n
# dtype: object, 'descripcion': Oversized Pokemon Umbreon License T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Oversized Pokemon Umbreon License T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Pokemon Umbreon License T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Tupac License T-shirt    https://www.boohooman.com/oversized-tupac-lice...
# dtype: object, 'precio': Oversized Tupac License T-shirt    \n\n\n£11.20\n( -30% )\n\n\n£16.00\n\n
# dtype: object, 'descripcion': Oversized Tupac License T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Oversized Tupac License T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Tupac License T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Heavy Nobility Renaissance T-shirt    https://www.boohooman.com/oversized-heavy-nobi...
# dtype: object, 'precio': Oversized Heavy Nobility Renaissance T-shirt    \n\n\n£8.40\n( -30% )\n\n\n£12.00\n\n
# dtype: object, 'descripcion': Oversized Heavy Nobility Renaissance T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Oversized Heavy Nobility Renaissance T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Heavy Nobility Renaissance T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Overdye Graphic T-shirt    https://www.boohooman.com/oversized-overdye-gr...
# dtype: object, 'precio': Oversized Overdye Graphic T-shirt    \n\n\n£8.40\n( -30% )\n\n\n£12.00\n\n
# dtype: object, 'descripcion': Oversized Overdye Graphic T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Oversized Overdye Graphic T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Overdye Graphic T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Chicago Print T-shirt    https://www.boohooman.com/oversized-chicago-pr...
# dtype: object, 'precio': Oversized Chicago Print T-shirt    \n\n\n£3.50\n( -30% )\n\n\n£5.00\n\n
# dtype: object, 'descripcion': Oversized Chicago Print T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Oversized Chicago Print T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Chicago Print T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Dragon Acid Wash Graphic T-shirt    https://www.boohooman.com/oversized-dragon-aci...
# dtype: object, 'precio': Oversized Dragon Acid Wash Graphic T-shirt    \n\n\n£9.80\n( -30% )\n\n\n£14.00\n\n
# dtype: object, 'descripcion': Oversized Dragon Acid Wash Graphic T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Oversized Dragon Acid Wash Graphic T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Dragon Acid Wash Graphic T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Homme Graphic T-shirt    https://www.boohooman.com/oversized-homme-grap...
# dtype: object, 'precio': Oversized Homme Graphic T-shirt    \n\n\n£8.40\n( -30% )\n\n\n£12.00\n\n
# dtype: object, 'descripcion': Oversized Homme Graphic T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Oversized Homme Graphic T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Homme Graphic T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized New York Graphic T-shirt    https://www.boohooman.com/oversized-new-york-g...
# dtype: object, 'precio': Oversized New York Graphic T-shirt    \n\n\n£7.00\n( -30% )\n\n\n£10.00\n\n
# dtype: object, 'descripcion': Oversized New York Graphic T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Oversized New York Graphic T-shirt    T-shirt
# dtype: object, 'imagen': Oversized New York Graphic T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Ofcl Man Teddy Graphic T-shirt    https://www.boohooman.com/oversized-ofcl-man-t...
# dtype: object, 'precio': Oversized Ofcl Man Teddy Graphic T-shirt    \n\n\n£7.00\n( -30% )\n\n\n£10.00\n\n
# dtype: object, 'descripcion': Oversized Ofcl Man Teddy Graphic T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Oversized Ofcl Man Teddy Graphic T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Ofcl Man Teddy Graphic T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Worldwide Graphic T-shirt    https://www.boohooman.com/oversized-worldwide-...
# dtype: object, 'precio': Oversized Worldwide Graphic T-shirt    \n\n\n£8.40\n( -30% )\n\n\n£12.00\n\n
# dtype: object, 'descripcion': Oversized Worldwide Graphic T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Oversized Worldwide Graphic T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Worldwide Graphic T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Acid Wash Graphic T-shirt    https://www.boohooman.com/oversized-acid-wash-...
# dtype: object, 'precio': Oversized Acid Wash Graphic T-shirt    \n\n\n£12.60\n( -30% )\n\n\n£18.00\n\n
# dtype: object, 'descripcion': Oversized Acid Wash Graphic T-shirt    The Boohoo Group are members of Better Cotton.
# dtype: object, 'categoria': Oversized Acid Wash Graphic T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Acid Wash Graphic T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Acid Wash Graphic T-shirt    https://www.boohooman.com/oversized-acid-wash-...
# dtype: object, 'precio': Oversized Acid Wash Graphic T-shirt    \n\n\n£8.40\n( -30% )\n\n\n£12.00\n\n
# dtype: object, 'descripcion': Oversized Acid Wash Graphic T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Oversized Acid Wash Graphic T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Acid Wash Graphic T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Acid Wash Rose Stem Print T-shirt    https://www.boohooman.com/oversized-acid-wash-...
# dtype: object, 'precio': Oversized Acid Wash Rose Stem Print T-shirt    \n\n\n£9.80\n( -30% )\n\n\n£14.00\n\n
# dtype: object, 'descripcion': Oversized Acid Wash Rose Stem Print T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Oversized Acid Wash Rose Stem Print T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Acid Wash Rose Stem Print T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Arizona Eagle Graphic T-shirt    https://www.boohooman.com/oversized-arizona-ea...
# dtype: object, 'precio': Oversized Arizona Eagle Graphic T-shirt    \n\n\n£6.00\n\n
# dtype: object, 'descripcion': Oversized Arizona Eagle Graphic T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Oversized Arizona Eagle Graphic T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Arizona Eagle Graphic T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Acid Wash Skull Graphic T-shirt    https://www.boohooman.com/oversized-acid-wash-...
# dtype: object, 'precio': Oversized Acid Wash Skull Graphic T-shirt    \n\n\n£7.00\n( -30% )\n\n\n£10.00\n\n
# dtype: object, 'descripcion': Oversized Acid Wash Skull Graphic T-shirt    Developing new t-shirt prints to keep you look...
# dtype: object, 'categoria': Oversized Acid Wash Skull Graphic T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Acid Wash Skull Graphic T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Car Graphic T-shirt    https://www.boohooman.com/oversized-car-graphi...
# dtype: object, 'precio': Oversized Car Graphic T-shirt    \n\n\n£5.00\n( -69% )\n\n\n£16.00\n\n
# dtype: object, 'descripcion': Oversized Car Graphic T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Oversized Car Graphic T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Car Graphic T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Extended Neck Homme Graphic T-shirt    https://www.boohooman.com/oversized-extended-n...
# dtype: object, 'precio': Oversized Extended Neck Homme Graphic T-shirt    \n\n\n£5.60\n( -30% )\n\n\n£8.00\n\n
# dtype: object, 'descripcion': Oversized Extended Neck Homme Graphic T-shirt    Developing new t-shirt prints to keep you look...
# dtype: object, 'categoria': Oversized Extended Neck Homme Graphic T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Extended Neck Homme Graphic T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Overdyed Official Puff Print T-shirt    https://www.boohooman.com/oversized-overdyed-o...
# dtype: object, 'precio': Oversized Overdyed Official Puff Print T-shirt    \n\n\n£7.00\n( -30% )\n\n\n£10.00\n\n
# dtype: object, 'descripcion': Oversized Overdyed Official Puff Print T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Oversized Overdyed Official Puff Print T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Overdyed Official Puff Print T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Acid Wash Graphic T-shirt    https://www.boohooman.com/oversized-acid-wash-...
# dtype: object, 'precio': Oversized Acid Wash Graphic T-shirt    \n\n\n£11.20\n( -30% )\n\n\n£16.00\n\n
# dtype: object, 'descripcion': Oversized Acid Wash Graphic T-shirt    The Boohoo Group are members of Better Cotton.
# dtype: object, 'categoria': Oversized Acid Wash Graphic T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Acid Wash Graphic T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Oversized Overdye Extended Neck T-shirt    https://www.boohooman.com/oversized-overdye-ex...
# dtype: object, 'precio': Oversized Overdye Extended Neck T-shirt    \n\n\n£7.00\n( -30% )\n\n\n£10.00\n\n
# dtype: object, 'descripcion': Oversized Overdye Extended Neck T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Oversized Overdye Extended Neck T-shirt    T-shirt
# dtype: object, 'imagen': Oversized Overdye Extended Neck T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Loose Official Dove Print T-shirt    https://www.boohooman.com/loose-official-dove-...
# dtype: object, 'precio': Loose Official Dove Print T-shirt    \n\n\n£8.40\n( -30% )\n\n\n£12.00\n\n
# dtype: object, 'descripcion': Loose Official Dove Print T-shirt    We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Loose Official Dove Print T-shirt    T-shirt
# dtype: object, 'imagen': Loose Official Dove Print T-shirt    https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# {'link': Ribbed Muscle Fit Vest     https://www.boohooman.com/ribbed-muscle-fit-ve...
# dtype: object, 'precio': Ribbed Muscle Fit Vest     \n\n\n£7.00\n( -30% )\n\n\n£10.00\n\n
# dtype: object, 'descripcion': Ribbed Muscle Fit Vest     We all know about t-shirts and vests, light la...
# dtype: object, 'categoria': Ribbed Muscle Fit Vest
# dtype: object, 'imagen': Ribbed Muscle Fit Vest     https://media.boohooman.com/i/boohooman///medi...
# dtype: object}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-5982cae87b0c> in <cell line: 7>()
#      13         productContainer = descproducto.find("div", {"class": "product-image"})
#      14         productLink = productContainer.find("a").get("href")
# ---> 15         boohooproduct = requests.get("https://www.boohooman.com" + productLink)
#      16         boohooproductsoup = BeautifulSoup(boohooproduct.content)
#      17         productName = boohooproductsoup.find("h1", {"class": "product-name"}).get_text()
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1272                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273                   self.__class__)
# -> 1274             return self.read(nbytes, buffer)
#    1275         else:
#    1276             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1128         try:
#    1129             if buffer is not None:
# -> 1130                 return self._sslobj.read(len, buffer)
#    1131             else:
#    1132                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
